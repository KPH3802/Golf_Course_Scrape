# %%
from splinter import Browser
from bs4 import BeautifulSoup
import re
import time
import requests
import time as t
from commonregex import CommonRegex
from streetaddress import StreetAddressFormatter, StreetAddressParser

# %%
# !which chromedriver
# Out:
# /opt/homebrew/bin/chromedriver

# %%
executable_path = {'executable_path': '/opt/homebrew/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
State = "ca" + "/"

City = "palm-desert"

st_city_url = url + State + City
st_city_url
# Out:
# 'https://www.golflink.com/golf-courses/ca/palm-desert'

# %%
browser.visit("https://www.golflink.com/golf-courses/ca/palm-springs/")

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# all_divs = []
# for course in soup.find_all("dic", class_="item", href=True):
course_dict = {}
dict_list = []

courses = soup.find_all("div", class_="resultContainer")
for course in courses:
    course_dict = {}
    name = course.find("a", class_="fly")
    address_blurb = course.find("div", class_ = "textcontainer")
#     print(address_blurb.text)
    text_add_blur = address_blurb.text
    clean_add_blurb = " ".join(text_add_blur.split())
    course_dict["Name"] = name.text
    course_dict["Blurb"] = clean_add_blurb
    course_dict["Holes"] = re.search(r'.*holes', clean_add_blurb)[0]
    try:
        pub_priv = re.findall('(Private|Public|Municipal)', clean_add_blurb)[0]
        course_dict["Public/Private"] = pub_priv
    except:
        course_dict["Public/Private"] = "N/A"
    course_dict["Phone"] = re.findall("\(\w{3}\) \w{3}-\w{4}",clean_add_blurb)
#     phone = re.findall("\(\w{3}\) \w{3}-\w{4}",clean_add_blurb)
#     word = clean_add_blurb[0]
#     print(clean_add_blurb)
#     before_keyword, keyword, after_keyword = word.partition(phone)
#     print(f"Before:{before_keyword}")
#     print(f"mid: {keyword}")
#     print(f"After: {after_keyword}")
#     # initializing substrings
#     sub1 = "is"
#     sub2 = "and"
  
#     # getting index of substrings
#     idx1 = test_str.index(sub1)
#     idx2 = test_str.index(phone)
  
#     # length of substring 1 is added to
#     # get string from next character
#     res = test_str[idx1 + len(sub1) + 1: idx2]
#     print(address)
    parse = CommonRegex(clean_add_blurb)
    print(parse.street_addresses)
    dict_list.append(course_dict)
# Out:
# ['301 N Belardo Rd']
# ['2700 E Mesquite Ave']
# ['1100 Clubhouse View Dr']
# ['2323 S Madrona Dr']
# ['1 Desert Lakes Dr']
# ['1097 E Murray Canyon Dr']
# ['1100 E Murray Canyon Dr']
# ['1885 Golf Club Dr']
# ['1885 Golf Club Dr']
# ['7603 30th Ave']
# ['7603 30th Ave']
# []
# []
# []
# []
# ['9411 Ramon Rd']
# ['9411 Ramon Rd']
# ['6200 Date Palm Dr']
# ['9300 Palm Dr']
# ['4600 Mission Hills Dr']
# ['4600 Mission Hills Dr']
# ['4600 Mission Hills Dr']
# ['0705 Ramon Rd']
# ['0240 Frank Sinatra Dr']
# ['1333 Dinah Shore Dr']
# ['9033 Morningside Dr']
# ['6400 Bubbling Wells Rd']
# ['0737 Country Club Dr']
# ['5500 Bubbling Wells Rd']
# ['1 Duke Dr']
# ['7977 Bob Hope Dr']
# ['1777 Frank Sinatra Dr']
# ['8500 Bob Hope Dr']
# ['6900 Desert Crest Ave']
# ['1601 Country Club Dr']
# ['0200 Dillon Rd']
# ['2765 Dunes View Rd']
# ['2610 Desert Moon Dr']
# ['2610 Desert Moon Dr']
# ['9002 Shadow Ridge Rd']
# ['2000 Bob Hope Dr']
# ['2000 Bob Hope Dr']
# ['2000 Bob Hope Dr']
# ['3450 Country Club Dr']
# ['8105 Portola Ave']
# ['1500 Monterey Ave']
# ['1500 Monterey Ave']
# ['1500 Monterey Ave']
# ['3750 Country Club Dr']
# ['4580 Varner Rd']
# ['8995 Desert Willow Dr']
# ['8995 Desert Willow Dr']
# []
# ['100 Chaparral Dr']
# []
# ['4855 Country Club Dr']
# ['4855 Country Club Dr']
# ['2500 Stone Eagle Dr']
# ['2500 Portola Ave']
# ['1111 Desert Falls Pkwy']
# ['161 Old Ranch Rd']
# ['161 Old Ranch Rd']
# ['161 Old Ranch Rd']
# ['3800 Ironwood St']
# ['4945 Sheryl Ave']
# ['5800 Avondale Dr']
# ['7000 Marrakesh Dr']
# ['9205 Palm Valley Dr']
# ['9205 Palm Valley Dr']
# []
# []
# ['255 Palowet Dr']
# ['255 Palowet Dr']
# ['6375 Country Club Dr']
# ['6375 Country Club Dr']
# ['4900 Desert Horizons Dr']
# ['5001 Vintage Dr']
# ['5001 Vintage Dr']
# ['3735 Irontree Dr']
# ['3735 Irontree Dr']
# []
# ['9400 Desert Butte Trl']
# ['7333 Country Club Dr']
# []
# []
# ['6000 E Eldorado Dr']
# ['7200 California Dr']
# ['6000 Club Dr']
# ['6000 Club Dr']
# ['1555 Woodhaven Dr']
# []
# []
# ['8259 Indigo Dr']
# ['2765 Adams St']
# ['2765 Adams St']
# ['2765 Adams St']
# []
# []
# []
# []

# %%
dict_list
# Out:
# [{'Name': "O'Donnell Golf Club, O'Donnell Course",
#   'Blurb': '9 holes over 2,655 yards with a par of 35 (Private) Write a Review 301 N Belardo Rd Palm Springs, CA 92262-5600 (760) 325-2259 0 miles from the center of Palm Springs. Write a Review',
#   'Holes': '9 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Mesquite Golf and Country Club, Mesquite Course',
#   'Blurb': '18 holes over 6,328 yards with a par of 72 (Public) Write a Review Check Tee Times 2700 E Mesquite Ave Ofc Palm Springs, CA 92264-5009 (760) 992-5158 2 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Escena Golf Club, Escena Course',
#   'Blurb': '18 holes over 7,211 yards with a par of 72 (Public) Write a Review 1100 Clubhouse View Dr Palm Springs, CA 92262-0574 (760) 778-2737 3 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Canyon Estates, Canyon Estates Course',
#   'Blurb': '9 holes (Private) Write a Review 2323 S Madrona Dr Palm Springs, CA 92264-9514 (760) 327-1346 3 miles from the center of Palm Springs. Write a Review',
#   'Holes': '9 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Seven Lakes Country Club, Seven Lakes Course',
#   'Blurb': '18 holes over 2,712 yards with a par of 58 (Private) Write a Review 1 Desert Lakes Dr Palm Springs, CA 92264-5520 (760) 328-9774 3 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Indian Canyons Golf Resort South Course, South Course',
#   'Blurb': '18 holes over 6,593 yards with a par of 72 (Public) Write a Review Check Tee Times 1097 E Murray Canyon Dr Palm Springs, CA 92264-4009 (760) 327-6550 3 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Indian Canyons Golf Resort North Course, North Course',
#   'Blurb': '18 holes over 6,869 yards with a par of 72 (Public) Write a Review Check Tee Times 1100 E Murray Canyon Dr Palm Springs, CA 92264-9484 (760) 833-8704 3 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': '
miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Desert Springs Golf Club, Palm Course',
#   'Blurb': '18 holes over 6,761 yards with a par of 72 (Public) Write a Review Check Tee Times 74855 Country Club Dr Palm Desert, CA 92260-1961 (800) 331-3112 12 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Desert Springs Golf Club, Valley Course',
#   'Blurb': '18 holes over 6,627 yards with a par of 72 (Public) Write a Review Check Tee Times 74855 Country Club Dr Palm Desert, CA 92260-1961 (800) 331-3112 12 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Stone Eagle Golf Club, Stone Eagle Course',
#   'Blurb': '18 holes over 6,976 yards with a par of 71 (Private) Write a Review 72500 Stone Eagle Dr Palm Desert, CA 92260-6280 (760) 773-6165 12 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Portola Country Club, Portola Course',
#   'Blurb': '18 holes over 2,134 yards with a par of 54 (Private) Write a Review 42500 Portola Ave Palm Desert, CA 92260-1998 (760) 346-5481 12 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Desert Falls Country Club, Desert Falls Course',
#   'Blurb': '18 holes over 7,017 yards with a par of 72 (Public) Write a Review Check Tee Times 1111 Desert Falls Pkwy Palm Desert, CA 92211-1709 (760) 340-5646 12 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'The Lakes Country Club, North Course',
#   'Blurb': '9 holes over 3,244 yards with a par of 36 (Private) Write a Review 161 Old Ranch Rd Palm Desert, CA 92211-3211 (760) 568-4321 12 miles from the center of Palm Springs. Write a Review',
#   'Holes': '9 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'The Lakes Country Club, East Course',
#   'Blurb': '9 holes over 3,175 yards with a par of 36 (Private) Write a Review 161 Old Ranch Rd Palm Desert, CA 92211-3211 (760) 568-4321 12 miles from the center of Palm Springs. Write a Review',
#   'Holes': '9 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'The Lakes Country Club, South Course',
#   'Blurb': '9 holes over 3,445 yards with a par of 36 (Private) Write a Review 161 Old Ranch Rd Palm Desert, CA 92211-3211 (760) 568-4321 12 miles from the center of Palm Springs. Write a Review',
#   'Holes': '9 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Shadow Mountain Golf Club, Shadow Mountain Course',
#   'Blurb': '18 holes over 5,441 yards with a par of 70 (Public) Write a Review Check Tee Times 73800 Ironwood St Palm Desert, CA 92260-5531 (760) 346-8242 12 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'The Golf Center At Palm Desert, Palm Desert Course',
#   'Blurb': '9 holes over 914 yards with a par of 27 (Public) Write a Review Check Tee Times 74945 Sheryl Ave Palm Desert, CA 92260-2073 (760) 347-3484 12 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '9 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Avondale Golf Club, Avondale Course',
#   'Blurb': '18 holes over 6,782 yards with a par of 72 (Private) Write a Review 75800 Avondale Dr Palm Desert, CA 92211-7024 (760) 345-2727 12 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Marrakesh Country Club, Marrakesh Course',
#   'Blurb': '18 holes over 3,614 yards with a par of 60 (Private) Write a Review 47000 Marrakesh Dr Palm Desert, CA 92260-5805 (760) 568-2660 13 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Palm Valley Country Club, Championship Course',
#   'Blurb': '18 holes over 6,545 yards with a par of 72 (Private) Write a Review 39205 Palm Valley Dr Palm Desert, CA 92211-4902 (760) 345-2742 13 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Palm Valley Country Club, Challenge Course',
#   'Blurb': '18 holes over 4,232 yards with a par of 63 (Private) Write a Review 39205 Palm Valley Dr Palm Desert, CA 92211-4902 (760) 345-2742 13 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Toscana Country Club, South Course',
#   'Blurb': '18 holes over 7,349 yards with a par of 72 (Private) Write a Review 76009 Via Club Villa Indian Wells, CA 92210-7851 (760) 404-1444 13 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Toscana Country Club, North Course',
#   'Blurb': '18 holes over 7,045 yards with a par of 72 (Private) Write a Review 76009 Via Club Villa Indian Wells, CA 92210-7851 (760) 404-1444 13 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': '
miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Indian Wells Country Club, Classic Course',
#   'Blurb': '18 holes over 6,478 yards with a par of 72 (Private) Write a Review 46000 Club Dr Indian Wells, CA 92210-8870 (760) 345-2561 14 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Indian Wells Country Club, Cove Course',
#   'Blurb': '18 holes over 6,558 yards with a par of 72 (Private) Write a Review 46000 Club Dr Indian Wells, CA 92210-8870 (760) 345-2561 14 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Woodhaven Country Club, Woodhaven Course',
#   'Blurb': '18 holes over 5,794 yards with a par of 70 (Public) Write a Review Check Tee Times 41555 Woodhaven Dr E Palm Desert, CA 92211-8119 (760) 345-7513 15 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Mountain Vista Golf Club At Sun City Palm Desert, San Gorgonio Course',
#   'Blurb': '18 holes over 6,669 yards with a par of 72 (Public) Write a Review Check Tee Times 38180 del Webb Blvd Palm Desert, CA 92211-1256 (760) 200-2200 15 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Mountain Vista Golf Club At Sun City Palm Desert, Santa Rosa Course',
#   'Blurb': '18 holes over 6,669 yards with a par of 72 (Public) Write a Review Check Tee Times 38180 del Webb Blvd Palm Desert, CA 92211-1256 (760) 200-2200 15 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Palm Royale Country Club, Palm Royale Course',
#   'Blurb': '18 holes over 1,992 yards with a par of 54 (Public) Write a Review Check Tee Times 78259 Indigo Dr La Quinta, CA 92253-3806 (760) 345-9701 16 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'Bermuda Dunes Country Club, Classic One Course',
#   'Blurb': '9 holes over 3,447 yards with a par of 36 (Private) Write a Review 42765 Adams St Bermuda Dunes, CA 92203-7937 (760) 360-2481 16 miles from the center of Palm Springs. Write a Review',
#   'Holes': '9 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Bermuda Dunes Country Club, Classic Two Course',
#   'Blurb': '9 holes over 3,480 yards with a par of 36 (Private) Write a Review 42765 Adams St Bermuda Dunes, CA 92203-7937 (760) 360-2481 16 miles from the center of Palm Springs. Write a Review',
#   'Holes': '9 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Bermuda Dunes Country Club, The Lake Course',
#   'Blurb': '9 holes over 3,269 yards with a par of 36 (Private) Write a Review 42765 Adams St Bermuda Dunes, CA 92203-7937 (760) 360-2481 16 miles from the center of Palm Springs. Write a Review',
#   'Holes': '9 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'PGA West Mountain & Dunes Golf Courses, Pete Dye Mountain Course',
#   'Blurb': '18 holes over 6,756 yards with a par of 72 (Public) Write a Review Check Tee Times 50200 Avenida Vista Bonita La Quinta, CA 92253-2600 (760) 564-7610 17 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'PGA West Mountain & Dunes Golf Courses, Pete Dye Dunes Course',
#   'Blurb': '18 holes over 6,074 yards with a par of 72 (Public) Write a Review Check Tee Times 50200 Avenida Vista Bonita La Quinta, CA 92253-2600 (760) 564-7610 17 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'},
#  {'Name': 'La Quinta Country Club, La Quinta Course',
#   'Blurb': '18 holes over 7,060 yards with a par of 72 (Private) Write a Review 77750 Avenue 50 La Quinta, CA 92253-2204 (760) 564-4151 17 miles from the center of Palm Springs. Write a Review',
#   'Holes': '18 holes',
#   'Public/Private': 'Private'},
#  {'Name': 'Shadow Hills Golf Club South Course, South Course',
#   'Blurb': '18 holes over 6,773 yards with a par of 71 (Public) Write a Review Check Tee Times 80875 Avenue 40 Indio, CA 92203-9439 (760) 200-3375 17 miles from the center of Palm Springs. Write a Review Check Tee Times',
#   'Holes': '18 holes',
#   'Public/Private': 'Public'}]
