# %%
from splinter import Browser
from bs4 import BeautifulSoup
import re
import time
import requests
import time as t
from commonregex import CommonRegex
from streetaddress import StreetAddressFormatter, StreetAddressParser
import pandas as pd

# %%
# !which chromedriver
# Out:
# /opt/homebrew/bin/chromedriver

# %%
executable_path = {'executable_path': '/opt/homebrew/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
State = "ca" + "/"

City = "palm-desert"

st_city_url = url + State + City
st_city_url
# Out:
# 'https://www.golflink.com/golf-courses/ca/palm-desert'

# %%
browser.visit("https://www.golflink.com/golf-courses/ca/palm-springs/")

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# all_divs = []
# for course in soup.find_all("dic", class_="item", href=True):
course_dict = {}
dict_list = []

courses = soup.find_all("div", class_="resultContainer")
for course in courses:
    course_dict = {}
    name = course.find("a", class_="fly")
    address_blurb = course.find("div", class_ = "textcontainer")
#     print(address_blurb.text)
    text_add_blur = address_blurb.text
    clean_add_blurb = " ".join(text_add_blur.split())
    course_dict["Name"] = name.text.split(',')[0]
    course_dict["Course Name"] = name.text.split(',')[1]
    course_dict["Holes"] = re.search(r'.*holes', clean_add_blurb)[0]
    try:
        pub_priv = re.findall('(Private|Public|Municipal)', clean_add_blurb)[0]
        course_dict["Public/Private"] = pub_priv
    except:
        course_dict["Public/Private"] = "N/A"
    course_dict["Phone"] = re.findall("\(\w{3}\) \w{3}-\w{4}",clean_add_blurb)[0]

    phone = re.findall("\(\w{3}\) \w{3}-\w{4}",clean_add_blurb)
    add = clean_add_blurb.rpartition(phone[0])[0]
    
    course_dict["Address"] = (re.split('Write a Review Check Tee Times |Write a Review ', add)[-1])
#     course_dict["Blurb"] = clean_add_blurb
#     word = clean_add_blurb[0]
#     print(clean_add_blurb)
#     before_keyword, keyword, after_keyword = word.partition(phone)
#     print(f"Before:{before_keyword}")
#     print(f"mid: {keyword}")
#     print(f"After: {after_keyword}")
#     # initializing substrings
#     sub1 = "is"
#     sub2 = "and"
  
#     # getting index of substrings
#     idx1 = test_str.index(sub1)
#     idx2 = test_str.index(phone)
  
#     # length of substring 1 is added to
#     # get string from next character
#     res = test_str[idx1 + len(sub1) + 1: idx2]
#     print(address)
#     parse = CommonRegex(clean_add_blurb)
#     print(parse.street_addresses)
#     addr_parser = StreetAddressParser()

#     addr = addr_parser.parse(clean_add_blurb)
#     address = re.findall("\d+[ ](?:[A-Za-z0-9.-]+[ ]?)+(?:Avenue|Lane|Road|Boulevard|Drive|Street|Ave|Dr|Rd|Blvd|Ln|St)\.?", clean_add_blurb)
#     print(address)
    dict_list.append(course_dict)

# %%
dict_list
# Out:
# [{'Name': "O'Donnell Golf Club",
#   'Course Name': " O'Donnell Course",
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 325-2259',
#   'Address': '301 N Belardo Rd Palm Springs, CA 92262-5600 '},
#  {'Name': 'Mesquite Golf and Country Club',
#   'Course Name': ' Mesquite Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 992-5158',
#   'Address': '2700 E Mesquite Ave Ofc Palm Springs, CA 92264-5009 '},
#  {'Name': 'Escena Golf Club',
#   'Course Name': ' Escena Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 778-2737',
#   'Address': '1100 Clubhouse View Dr Palm Springs, CA 92262-0574 '},
#  {'Name': 'Canyon Estates',
#   'Course Name': ' Canyon Estates Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 327-1346',
#   'Address': '2323 S Madrona Dr Palm Springs, CA 92264-9514 '},
#  {'Name': 'Seven Lakes Country Club',
#   'Course Name': ' Seven Lakes Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 328-9774',
#   'Address': '1 Desert Lakes Dr Palm Springs, CA 92264-5520 '},
#  {'Name': 'Indian Canyons Golf Resort South Course',
#   'Course Name': ' South Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 327-6550',
#   'Address': '1097 E Murray Canyon Dr Palm Springs, CA 92264-4009 '},
#  {'Name': 'Indian Canyons Golf Resort North Course',
#   'Course Name': ' North Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 833-8704',
#   'Address': '1100 E Murray Canyon Dr Palm Springs, CA 92264-9484 '},
#  {'Name': 'Tahquitz Creek Golf Resort',
#   'Course Name': ' Legends Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Municipal',
#   'Phone': '(760) 328-1005',
#   'Address': '1885 Golf Club Dr Palm Springs, CA 92264-3860 '},
#  {'Name': 'Tahquitz Creek Golf Resort',
#   'Course Name': ' Resort Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Municipal',
#   'Phone': '(760) 328-1005',
#   'Address': '1885 Golf Club Dr Palm Springs, CA 92264-3860 '},
#  {'Name': 'Cimarron Golf Resort',
#   'Course Name': ' Boulder Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 770-6060',
#   'Address': '67603 30th Ave Cathedral City, CA 92234-5828 '},
#  {'Name': 'Cimarron Golf Resort',
#   'Course Name': ' Pebble Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 770-6060',
#   'Address': '67603 30th Ave Cathedral City, CA 92234-5828 '},
#  {'Name': 'Desert Princess Palm Springs',
#   'Course Name': ' Los Lagos Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(800) 465-3012',
#   'Address': '28555 Landau Blvd Cathedral City, CA 92234-3508 '},
#  {'Name': 'Desert Princess Palm Springs',
#   'Course Name': ' El Cielo Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(800) 465-3012',
#   'Address': '28555 Landau Blvd Cathedral City, CA 92234-3508 '},
#  {'Name': 'Desert Princess Palm Springs',
#   'Course Name': ' La Vista Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(800) 465-3012',
#   'Address': '28555 Landau Blvd Cathedral City, CA 92234-3508 '},
#  {'Name': 'Cathedral Canyon Golf Club',
#   'Course Name': ' Cathedral Canyon Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 328-6571',
#   'Address': '68311 Paseo Real Cathedral City, CA 92234-6767 '},
#  {'Name': 'Outdoor Resort Palm Springs',
#   'Course Name': ' Outdoor Resorts 1 Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 324-8638',
#   'Address': '69411 Ramon Rd Cathedral City, CA 92234-3350 '},
#  {'Name': 'Outdoor Resort Palm Springs',
#   'Course Name': ' Outdoor Resorts 2 Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 324-8638',
#   'Address': '69411 Ramon Rd Cathedral City, CA 92234-3350 '},
#  {'Name': 'Date Palm Country Club',
#   'Course Name': ' Date Palm Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 328-1315',
#   'Address': '36200 Date Palm Dr Cathedral City, CA 92234-1506 '},
#  {'Name': 'Desert Dunes Golf Club',
#   'Course Name': ' Desert Dunes Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 251-5370',
#   'Address': '19300 Palm Dr Desert Hot Springs, CA 92240-7333 '},
#  {'Name': 'Mission Hills Country Club',
#   'Course Name': ' Tournament Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 324-9400',
#   'Address': '34600 Mission Hills Dr Rancho Mirage, CA 92270-1375 '},
#  {'Name': 'Mission Hills Country Club',
#   'Course Name': ' Arnold Palmer Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 324-9400',
#   'Address': '34600 Mission Hills Dr Rancho Mirage, CA 92270-1375 '},
#  {'Name': 'Mission Hills Country Club',
#   'Course Name': ' Pete Dye Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 324-9400',
#   'Address': '34600 Mission Hills Dr Rancho Mirage, CA 92270-1375 '},
#  {'Name': 'Mission Hills North Gary Player Signature Course',
#   'Course Name': ' Gary Player Signature Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 699-0111',
#   'Address': '70705 Ramon Rd Rancho Mirage, CA 92270-5602 '},
#  {'Name': 'Tamarisk Country Club',
#   'Course Name': ' Tamarisk Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 328-2141',
#   'Address': '70240 Frank Sinatra Dr Rancho Mirage, CA 92270-2599 '},
#  {'Name': 'The Westin Mission Hills Resort Pete Dye Course',
#   'Course Name': ' Pete Dye Resort Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 328-3198',
#   'Address': '71333 Dinah Shore Dr Rancho Mirage, CA 92270-1501 '},
#  {'Name': 'The Club At Morningside',
#   'Course Name': ' Morningside Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 321-1555',
#   'Address': '39033 Morningside Dr Rancho Mirage, CA 92270-3050 '},
#  {'Name': 'The Sands RV & Golf Resort',
#   'Course Name': ' Sands Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(800) 772-7808',
#   'Address': '16400 Bubbling Wells Rd Desert Hot Springs, CA 92240-9555 '},
#  {'Name': 'Thunderbird Country Club',
#   'Course Name': ' Thunderbird Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 328-2161',
#   'Address': '70737 Country Club Dr Rancho Mirage, CA 92270-3500 '},
#  {'Name': 'Hidden Springs Country Club',
#   'Course Name': ' Hidden Springs Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 288-4653',
#   'Address': '15500 Bubbling Wells Rd Desert Hot Springs, CA 92240-7043 '},
#  {'Name': 'The Springs Country Club',
#   'Course Name': ' Springs Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 324-8292',
#   'Address': '1 Duke Dr Rancho Mirage, CA 92270-3647 '},
#  {'Name': 'Sunnylands Golf Course At Annenberg Retreat',
#   'Course Name': ' Sunnyland Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 328-2829',
#   'Address': '37977 Bob Hope Dr Rancho Mirage, CA 92270-2008 '},
#  {'Name': 'Desert Island Country Club',
#   'Course Name': ' The S Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 328-0841',
#   'Address': '71777 Frank Sinatra Dr Rancho Mirage, CA 92270-3144 '},
#  {'Name': 'Rancho Mirage Country Club',
#   'Course Name': ' Rancho Mirage Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 324-4711',
#   'Address': '38500 Bob Hope Dr Rancho Mirage, CA 92270-3259 '},
#  {'Name': 'Desert Crest Country Club',
#   'Course Name': ' Desert Crest Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 329-8711',
#   'Address': '16900 Desert Crest Ave Desert Hot Springs, CA 92241-8235 '},
#  {'Name': 'Sunrise Country Club',
#   'Course Name': ' Sunrise Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 328-1139',
#   'Address': '71601 Country Club Dr Rancho Mirage, CA 92270-3598 '},
#  {'Name': 'Caliente Springs Resort',
#   'Course Name': ' Caliente Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 660-4522',
#   'Address': '70200 Dillon Rd Desert Hot Springs, CA 92241-7646 '},
#  {'Name': 'Porcupine Creek Golf Club & Private Residence',
#   'Course Name': ' Porcupine Creek Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 250-0594',
#   'Address': '42765 Dunes View Rd Rancho Mirage, CA 92270-4311 '},
#  {'Name': 'Tri Palm Estates & Country Club',
#   'Course Name': ' Tri Palm Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 343-3497',
#   'Address': '32610 Desert Moon Dr Thousand Palms, CA 92276-3711 '},
#  {'Name': 'Tri Palm Estates & Country Club',
#   'Course Name': ' Par-3 Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 343-3497',
#   'Address': '32610 Desert Moon Dr Thousand Palms, CA 92276-3711 '},
#  {'Name': "Marriott's Shadow Ridge Golf Club",
#   'Course Name': ' Marriott Shadow Ridge Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 674-2700',
#   'Address': '9002 Shadow Ridge Rd Palm Desert, CA 92211-2057 '},
#  {'Name': 'Rancho Las Palmas Country Club',
#   'Course Name': ' North Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(866) 423-1195',
#   'Address': '42000 Bob Hope Dr Rancho Mirage, CA 92270-4466 '},
#  {'Name': 'Rancho Las Palmas Country Club',
#   'Course Name': ' South Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(866) 423-1195',
#   'Address': '42000 Bob Hope Dr Rancho Mirage, CA 92270-4466 '},
#  {'Name': 'Rancho Las Palmas Country Club',
#   'Course Name': ' West Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(866) 423-1195',
#   'Address': '42000 Bob Hope Dr Rancho Mirage, CA 92270-4466 '},
#  {'Name': 'Suncrest Country Club',
#   'Course Name': ' Suncrest Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 346-5866',
#   'Address': '73450 Country Club Dr Palm Desert, CA 92260-8699 '},
#  {'Name': 'Santa Rosa Country Club',
#   'Course Name': ' Santa Rosa Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 568-5717',
#   'Address': '38105 Portola Ave Palm Desert, CA 92260-1201 '},
#  {'Name': 'Monterey Country Club',
#   'Course Name': ' West Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 346-1115',
#   'Address': '41500 Monterey Ave Palm Desert, CA 92260-2199 '},
#  {'Name': 'Monterey Country Club',
#   'Course Name': ' East Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 346-1115',
#   'Address': '41500 Monterey Ave Palm Desert, CA 92260-2199 '},
#  {'Name': 'Monterey Country Club',
#   'Course Name': ' South Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 346-1115',
#   'Address': '41500 Monterey Ave Palm Desert, CA 92260-2199 '},
#  {'Name': 'Palm Desert Greens',
#   'Course Name': ' Palm Desert Greens Countr Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 346-2941',
#   'Address': '73750 Country Club Dr Palm Desert, CA 92260-8663 '},
#  {'Name': 'Ivey Ranch Country Club',
#   'Course Name': ' Ivey Ranch Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 343-2013',
#   'Address': '74580 Varner Rd Thousand Palms, CA 92276-4201 '},
#  {'Name': 'Desert Willow Golf Resort',
#   'Course Name': ' Firecliff Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Municipal',
#   'Phone': '(800) 320-3323',
#   'Address': '38995 Desert Willow Dr Palm Desert, CA 92260-1674 '},
#  {'Name': 'Desert Willow Golf Resort',
#   'Course Name': ' Mountain View Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Municipal',
#   'Phone': '(800) 320-3323',
#   'Address': '38995 Desert Willow Dr Palm Desert, CA 92260-1674 '},
#  {'Name': 'Mission Lakes Country Club',
#   'Course Name': ' Mission Lakes Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 329-8061',
#   'Address': '8484 Clubhouse Blvd Desert Hot Springs, CA 92240-1100 '},
#  {'Name': 'Chaparral Country Club',
#   'Course Name': ' Chaparral Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 340-1501',
#   'Address': '100 Chaparral Dr Palm Desert, CA 92260-0322 '},
#  {'Name': 'Classic Club',
#   'Course Name': ' Classic Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 601-3600',
#   'Address': '75200 Classic Club Blvd Palm Desert, CA 92211-4124 '},
#  {'Name': 'Desert Springs Golf Club',
#   'Course Name': ' Palm Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(800) 331-3112',
#   'Address': '74855 Country Club Dr Palm Desert, CA 92260-1961 '},
#  {'Name': 'Desert Springs Golf Club',
#   'Course Name': ' Valley Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(800) 331-3112',
#   'Address': '74855 Country Club Dr Palm Desert, CA 92260-1961 '},
#  {'Name': 'Stone Eagle Golf Club',
#   'Course Name': ' Stone Eagle Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 773-6165',
#   'Address': '72500 Stone Eagle Dr Palm Desert, CA 92260-6280 '},
#  {'Name': 'Portola Country Club',
#   'Course Name': ' Portola Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 346-5481',
#   'Address': '42500 Portola Ave Palm Desert, CA 92260-1998 '},
#  {'Name': 'Desert Falls Country Club',
#   'Course Name': ' Desert Falls Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 340-5646',
#   'Address': '1111 Desert Falls Pkwy Palm Desert, CA 92211-1709 '},
#  {'Name': 'The Lakes Country Club',
#   'Course Name': ' North Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 568-4321',
#   'Address': '161 Old Ranch Rd Palm Desert, CA 92211-3211 '},
#  {'Name': 'The Lakes Country Club',
#   'Course Name': ' East Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 568-4321',
#   'Address': '161 Old Ranch Rd Palm Desert, CA 92211-3211 '},
#  {'Name': 'The Lakes Country Club',
#   'Course Name': ' South Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 568-4321',
#   'Address': '161 Old Ranch Rd Palm Desert, CA 92211-3211 '},
#  {'Name': 'Shadow Mountain Golf Club',
#   'Course Name': ' Shadow Mountain Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 346-8242',
#   'Address': '73800 Ironwood St Palm Desert, CA 92260-5531 '},
#  {'Name': 'The Golf Center At Palm Desert',
#   'Course Name': ' Palm Desert Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 347-3484',
#   'Address': '74945 Sheryl Ave Palm Desert, CA 92260-2073 '},
#  {'Name': 'Avondale Golf Club',
#   'Course Name': ' Avondale Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 345-2727',
#   'Address': '75800 Avondale Dr Palm Desert, CA 92211-7024 '},
#  {'Name': 'Marrakesh Country Club',
#   'Course Name': ' Marrakesh Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 568-2660',
#   'Address': '47000 Marrakesh Dr Palm Desert, CA 92260-5805 '},
#  {'Name': 'Palm Valley Country Club',
#   'Course Name': ' Championship Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 345-2742',
#   'Address': '39205 Palm Valley Dr Palm Desert, CA 92211-4902 '},
#  {'Name': 'Palm Valley Country Club',
#   'Course Name': ' Challenge Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 345-2742',
#   'Address': '39205 Palm Valley Dr Palm Desert, CA 92211-4902 '},
#  {'Name': 'Toscana Country Club',
#   'Course Name': ' South Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 404-1444',
#   'Address': '76009 Via Club Villa Indian Wells, CA 92210-7851 '},
#  {'Name': 'Toscana Country Club',
#   'Course Name': ' North Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 404-1444',
#   'Address': '76009 Via Club Villa Indian Wells, CA 92210-7851 '},
#  {'Name': 'Bighorn Golf Club',
#   'Course Name': ' Canyons Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 773-2468',
#   'Address': '255 Palowet Dr Palm Desert, CA 92260-7311 '},
#  {'Name': 'Bighorn Golf Club',
#   'Course Name': ' Mountains Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 773-2468',
#   'Address': '255 Palowet Dr Palm Desert, CA 92260-7311 '},
#  {'Name': 'Indian Ridge Country Club',
#   'Course Name': ' Grove Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 772-7272',
#   'Address': '76375 Country Club Dr Palm Desert, CA 92211-9512 '},
#  {'Name': 'Indian Ridge Country Club',
#   'Course Name': ' Arroyo Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 772-7272',
#   'Address': '76375 Country Club Dr Palm Desert, CA 92211-9512 '},
#  {'Name': 'Desert Horizons Country Club',
#   'Course Name': ' Desert Horizons Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 340-4646',
#   'Address': '44900 Desert Horizons Dr Indian Wells, CA 92210-7401 '},
#  {'Name': 'The Vintage Club',
#   'Course Name': ' Mountain Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 862-2076',
#   'Address': '75001 Vintage Dr W Indian Wells, CA 92210-7304 '},
#  {'Name': 'The Vintage Club',
#   'Course Name': ' Desert Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 862-2076',
#   'Address': '75001 Vintage Dr W Indian Wells, CA 92210-7304 '},
#  {'Name': 'Ironwood Country Club',
#   'Course Name': ' North Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 766-1062',
#   'Address': '73735 Irontree Dr Palm Desert, CA 92260-6910 '},
#  {'Name': 'Ironwood Country Club',
#   'Course Name': ' South Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 766-1062',
#   'Address': '73735 Irontree Dr Palm Desert, CA 92260-6910 '},
#  {'Name': 'The Oasis Country Club',
#   'Course Name': ' Oasis Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 345-2715',
#   'Address': '42330 Casbah Way Palm Desert, CA 92211-7660 '},
#  {'Name': 'The Reserve Club',
#   'Course Name': ' Reserve Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 674-2240',
#   'Address': '49400 Desert Butte Trl Indian Wells, CA 92210-7075 '},
#  {'Name': 'Palm Desert Resort Country Club',
#   'Course Name': ' Palm Desert Resort Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 345-2791',
#   'Address': '77333 Country Club Dr Palm Desert, CA 92211-9231 '},
#  {'Name': 'Indian Wells Golf Resort',
#   'Course Name': ' Players Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Municipal',
#   'Phone': '(760) 346-4653',
#   'Address': '44500 Indian Wells Ln Indian Wells, CA 92210-8746 '},
#  {'Name': 'Indian Wells Golf Resort',
#   'Course Name': ' Celebrity Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Municipal',
#   'Phone': '(760) 346-4653',
#   'Address': '44500 Indian Wells Ln Indian Wells, CA 92210-8746 '},
#  {'Name': 'Eldorado Country Club',
#   'Course Name': ' Eldorado Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 346-8081',
#   'Address': '46000 E Eldorado Dr Indian Wells, CA 92210-8631 '},
#  {'Name': 'Palm Desert Country Club',
#   'Course Name': ' Palm Desert Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 345-0222',
#   'Address': '77200 California Dr Palm Desert, CA 92211-7898 '},
#  {'Name': 'Indian Wells Country Club',
#   'Course Name': ' Classic Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 345-2561',
#   'Address': '46000 Club Dr Indian Wells, CA 92210-8870 '},
#  {'Name': 'Indian Wells Country Club',
#   'Course Name': ' Cove Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 345-2561',
#   'Address': '46000 Club Dr Indian Wells, CA 92210-8870 '},
#  {'Name': 'Woodhaven Country Club',
#   'Course Name': ' Woodhaven Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 345-7513',
#   'Address': '41555 Woodhaven Dr E Palm Desert, CA 92211-8119 '},
#  {'Name': 'Mountain Vista Golf Club At Sun City Palm Desert',
#   'Course Name': ' San Gorgonio Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 200-2200',
#   'Address': '38180 del Webb Blvd Palm Desert, CA 92211-1256 '},
#  {'Name': 'Mountain Vista Golf Club At Sun City Palm Desert',
#   'Course Name': ' Santa Rosa Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 200-2200',
#   'Address': '38180 del Webb Blvd Palm Desert, CA 92211-1256 '},
#  {'Name': 'Palm Royale Country Club',
#   'Course Name': ' Palm Royale Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 345-9701',
#   'Address': '78259 Indigo Dr La Quinta, CA 92253-3806 '},
#  {'Name': 'Bermuda Dunes Country Club',
#   'Course Name': ' Classic One Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 360-2481',
#   'Address': '42765 Adams St Bermuda Dunes, CA 92203-7937 '},
#  {'Name': 'Bermuda Dunes Country Club',
#   'Course Name': ' Classic Two Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 360-2481',
#   'Address': '42765 Adams St Bermuda Dunes, CA 92203-7937 '},
#  {'Name': 'Bermuda Dunes Country Club',
#   'Course Name': ' The Lake Course',
#   'Holes': '9 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 360-2481',
#   'Address': '42765 Adams St Bermuda Dunes, CA 92203-7937 '},
#  {'Name': 'PGA West Mountain & Dunes Golf Courses',
#   'Course Name': ' Pete Dye Mountain Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 564-7610',
#   'Address': '50200 Avenida Vista Bonita La Quinta, CA 92253-2600 '},
#  {'Name': 'PGA West Mountain & Dunes Golf Courses',
#   'Course Name': ' Pete Dye Dunes Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 564-7610',
#   'Address': '50200 Avenida Vista Bonita La Quinta, CA 92253-2600 '},
#  {'Name': 'La Quinta Country Club',
#   'Course Name': ' La Quinta Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Private',
#   'Phone': '(760) 564-4151',
#   'Address': '77750 Avenue 50 La Quinta, CA 92253-2204 '},
#  {'Name': 'Shadow Hills Golf Club South Course',
#   'Course Name': ' South Course',
#   'Holes': '18 holes',
#   'Public/Private': 'Public',
#   'Phone': '(760) 200-3375',
#   'Address': '80875 Avenue 40 Indio, CA 92203-9439 '}]

# %%
df = pd.DataFrame.from_dict(dict_list)
df
# Out:
#                                       Name                Course Name  \
# 0                      O'Donnell Golf Club           O'Donnell Course
# 1           Mesquite Golf and Country Club            Mesquite Course
# 2                         Escena Golf Club              Escena Course
# 3                           Canyon Estates      Canyon Estates Course
# 4                 Seven Lakes Country Club         Seven Lakes Course
# ..                                     ...                        ...
# 95              Bermuda Dunes Country Club            The Lake Course
# 96  PGA West Mountain & Dunes Golf Courses   Pete Dye Mountain Course
# 97  PGA West Mountain & Dunes Golf Courses      Pete Dye Dunes Course
# 98                  La Quinta Country Club           La Quinta Course
# 99     Shadow Hills Golf Club South Course               South Course
#
#        Holes Public/Private           Phone  \
# 0    9 holes        Private  (760) 325-2259
# 1   18 holes         Public  (760) 992-5158
# 2   18 holes         Public  (760) 778-2737
# 3    9 holes        Private  (760) 327-1346
# 4   18 holes        Private  (760) 328-9774
# ..       ...            ...             ...
# 95   9 holes        Private  (760) 360-2481
# 96  18 holes         Public  (760) 564-7610
# 97  18 holes         Public  (760) 564-7610
# 98  18 holes        Private  (760) 564-4151
# 99  18 holes         Public  (760) 200-3375
#
#                                               Address
# 0       301 N Belardo Rd Palm Springs, CA 92262-5600
# 1   2700 E Mesquite Ave Ofc Palm Springs, CA 92264...
# 2   1100 Clubhouse View Dr Palm Springs, CA 92262-...
# 3      2323 S Madrona Dr Palm Springs, CA 92264-9514
# 4      1 Desert Lakes Dr Palm Springs, CA 92264-5520
# ..                                                ...
# 95       42765 Adams St Bermuda Dunes, CA 92203-7937
# 96  50200 Avenida Vista Bonita La Quinta, CA 92253...
# 97  50200 Avenida Vista Bonita La Quinta, CA 92253...
# 98          77750 Avenue 50 La Quinta, CA 92253-2204
# 99              80875 Avenue 40 Indio, CA 92203-9439
#
# [100 rows x 6 columns]

# %%
df.to_csv("Data_Scraped/Palm_Springs_courses.csv", index=False)
